# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Modelling lab: Can we predict risk of bankruptcy?

# %% [markdown]
# In this exercise we will try to predict companies that go bankrupt in the next 5 years, based on various numeric financial attributes. The dataset describes Polish companies and their financial accounts, and further information is [available here](https://archive.ics.uci.edu/ml/datasets/Polish+companies+bankruptcy+data). For this exercise we chose only the companies that went bankrupt within 5 years (one of the five available datasets on the site).
#
# # Part 1 - Exploratory data analysis
#
# ### 1. Load the data
#
# Look at the usual things:
#
# - how many rows/columns?
# - what are the data types?
# - any missing values?

# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv("../data/bankruptcy.csv")
print(df.shape)
df.head(2).T
# Out:
# (7027, 65)
#                                                                 0            1
# net profit / total assets                                0.200550     0.209120
# total liabilities / total assets                         0.379510     0.499880
# working capital / total assets                           0.396410     0.472250
# current assets / short-term liabilities                  2.047200     1.944700
# [(cash + short-term securities + receivables - ...      32.351000    14.786000
# retained earnings / total assets                         0.388250     0.000000
# EBIT / total assets                                      0.249760     0.258340
# book value of equity / total liabilities                 1.330500     0.996010
# sales / total assets                                     1.138900     1.699600
# equity / total assets                                    0.504940     0.497880
# (gross profit + extraordinary items + financial...       0.249760     0.261140
# gross profit / short-term liabilities                    0.659800     0.516800
# (gross profit + depreciation) / sales                    0.166600     0.158350
# (gross profit + interest) / total assets                 0.249760     0.258340
# (total liabilities * 365) / (gross profit + dep...     497.420000   677.960000
# (gross profit + depreciation) / total liabilities        0.733780     0.538380
# total assets / total liabilities                         2.634900     2.000500
# gross profit / total assets                              0.249760     0.258340
# gross profit / sales                                     0.149420     0.152000
# (inventory * 365) / sales                               43.370000    87.981000
# sales (n) / sales (n-1)                                  1.247900     1.429300
# profit on operating activities / total assets            0.214020     0.248060
# net profit / sales                                       0.119980     0.123040
# gross profit (in 3 years) / total assets                 0.477060          NaN
# (equity - share capital) / total assets                  0.504940     0.395420
# (net profit + depreciation) / total liabilities          0.604110     0.439920
# profit on operating activities / financial expe...       1.458200    88.444000
# working capital / fixed assets                           1.761500    16.946000
# logarithm of total assets                                5.944300     3.688400
# (total liabilities - cash) / sales                       0.117880     0.269690
# (gross profit + interest) / sales                        0.149420     0.152000
# (current liabilities * 365) / cost of products ...      94.140000   122.170000
# operating expenses / short-term liabilities              3.877200     2.987600
# operating expenses / total liabilities                   0.563930     2.987600
# profit on sales / total assets                           0.214020     0.206160
# total sales / total assets                               1.741000     1.699600
# (current assets - inventories) / long-term liab...     593.270000          NaN
# constant capital / total assets                          0.505910     0.497880
# profit on sales / sales                                  0.128040     0.121300
# (current assets - inventory - receivables) / sh...       0.662950     0.086422
# total liabilities / ((profit on operating activ...       0.051402     0.064371
# profit on operating activities / sales                   0.128040     0.145950
# rotation receivables + inventory turnover in days      114.420000   199.490000
# (receivables * 365) / sales                             71.050000   111.510000
# net profit / inventory                                   1.009700     0.510450
# (current assets - inventory) / short-term liabi...       1.522500     1.125200
# (inventory * 365) / cost of products sold               49.394000   100.130000
# EBITDA (profit on operating activities - deprec...       0.185300     0.237270
# EBITDA (profit on operating activities - deprec...       0.110850     0.139610
# current assets / total liabilities                       2.042000     1.944700
# short-term liabilities / total assets                    0.378540     0.499880
# (short-term liabilities * 365) / cost of produc...       0.257920     0.334720
# equity / fixed assets                                    2.243700    17.866000
# constant capital / fixed assets                          2.248000    17.866000
# working capital                                     348690.000000  2304.600000
# (sales - cost of products sold) / sales                  0.121960     0.121300
# (current assets - inventory - short-term liabil...       0.397180     0.420020
# total costs /total sales                                 0.878040     0.853000
# long-term liabilities / equity                           0.001924     0.000000
# sales / inventory                                        8.416000     4.148600
# sales / receivables                                      5.137200     3.273200
# (short-term liabilities *365) / sales                   82.658000   107.350000
# sales / short-term liabilities                           4.415800     3.400000
# sales / fixed assets                                     7.427700    60.987000
# bankruptcy_label                                         0.000000     0.000000

# %% [markdown]
# So they're all numeric except the binary target, which is an integer

# %%
# check out the target variable
df['bankruptcy_label'].value_counts()
# Out:
# 0    6756
# 1     271
# Name: bankruptcy_label, dtype: int64

# %%
# imbalanced classes!
df['bankruptcy_label'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum().values
# Out:
# array([   3,    3,    3,   30,    8,    3,    3,   25,    1,    3,   39,
#          30,    0,    3,    2,   25,   25,    3,    0,    0, 1622,    3,
#           0,  124,    3,   25,  311,   34,    3,    0,    0,   38,   30,
#          25,    3,    3, 2740,    3,    0,   30,   84,    0,    0,    0,
#         134,   31,   29,    3,    0,   25,    3,   29,   34,   34,    0,
#           0,    1,    0,    1,  135,   22,    0,   30,   34,    0],
#       dtype=int64)

# %% [markdown]
# Some columns are missing more values than others, let's look at the worst offenders

# %%
print(len(df))
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# 7027
# (current assets - inventories) / long-term liabilities    2740
# sales (n) / sales (n-1)                                   1622
# profit on operating activities / financial expenses        311
# sales / inventory                                          135
# net profit / inventory                                     134
# dtype: int64

# %% [markdown]
# We'll deal with missing values later, depending on which features we use for prediction

# %% [markdown]
# ### 2. Examine the target
#
# The target is the final column, `bankruptcy_label` (1 if the company went bankrupt within 5 years).
#
# What is the distribution of the target?

# %%
df["bankruptcy_label"].value_counts(normalize=True)
# Out:
# 0    0.961434
# 1    0.038566
# Name: bankruptcy_label, dtype: float64

# %% [markdown]
# So it's an imbalanced dataset, only <4% of the companies went bankrupt within 5 years

# %% [markdown]
# ### 3. Create a heatmap showing the correlations within your features
#
# It's generally a good idea to see how your features correlate to each other, to identify columns that perhaps encode the same information. We'll do this by calculating the correlation matrix (how every column correlates with every other) and inspect it visually as a heatmap.
#
# #### 3. a. Get a correlation matrix of your features (hint: there's a built in `pandas` function for that!

# %%
corr_matrix = df.drop("bankruptcy_label", axis=1).corr()
corr_matrix.head(2)
# Out:
#                                   net profit / total assets  total liabilities / total assets  working capital / total assets  current assets / short-term liabilities  [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  retained earnings / total assets  EBIT / total assets  book value of equity / total liabilities  sales / total assets  equity / total assets  (gross profit + extraordinary items + financial expenses) / total assets  gross profit / short-term liabilities  (gross profit + depreciation) / sales  (gross profit + interest) / total assets  (total liabilities * 365) / (gross profit + depreciation)  (gross profit + depreciation) / total liabilities  total assets / total liabilities  gross profit / total assets  gross profit / sales  (inventory * 365) / sales  sales (n) / sales (n-1)  profit on operating activities / total assets  net profit / sales  gross profit (in 3 years) / total assets  \
# net profit / total assets                          1.000000                         -0.155932                        0.159913                                 0.014650                                           0.008364                                                                                            0.129868             0.422068                                  0.016007             -0.561939              -0.349011                                           0.397936                                                      0.053170                               0.000667                                  0.422068                                           0.000146                                                   0.047888                          0.015390                     0.422068              0.003726                  -0.000068                -0.004889                                       0.463856            0.003743                                  0.266205
# total liabilities / total assets                  -0.155932                          1.000000                       -0.985782                                -0.010019                                          -0.052235                                                                                           -0.772227            -0.193355                                 -0.008612             -0.073338              -0.221383                                          -0.103102                                                     -0.010755                              -0.002873                                 -0.193355                                           0.000332                                                  -0.007249                         -0.010606                    -0.193355             -0.017806                   0.000656                -0.003277                                      -0.106255           -0.018350                                 -0.176283
#
#                                   (equity - share capital) / total assets  (net profit + depreciation) / total liabilities  profit on operating activities / financial expenses  working capital / fixed assets  logarithm of total assets  (total liabilities - cash) / sales  (gross profit + interest) / sales  (current liabilities * 365) / cost of products sold  operating expenses / short-term liabilities  operating expenses / total liabilities  profit on sales / total assets  total sales / total assets  (current assets - inventories) / long-term liabilities  constant capital / total assets  profit on sales / sales  (current assets - inventory - receivables) / short-term liabilities  total liabilities / ((profit on operating activities + depreciation) * (12/365))  profit on operating activities / sales  rotation receivables + inventory turnover in days  (receivables * 365) / sales  net profit / inventory  (current assets - inventory) / short-term liabilities  \
# net profit / total assets                                       -0.646808                                         0.033544                                           0.008489                          0.004493                   0.087485                           -0.000417                           0.003745                                          -0.138953                                       0.042241                                0.039684                       -0.059102                   -0.561856                                          -0.000551                             -0.349053                 0.000634                                           0.005682                                                            -0.005399                                                               0.000724                                          -0.000066                    -0.000066                0.001046                                           0.011966
# total liabilities / total assets                                -0.195784                                        -0.007001                                          -0.005003                         -0.017878                  -0.050353                            0.002882                          -0.017816                                           0.856251                                      -0.017536                               -0.003286                       -0.114210                   -0.073245                                          -0.032585                             -0.221321                 0.001318                                          -0.004600                                                             0.039239                                                               0.001164                                           0.000668                     0.000673               -0.002783                                          -0.007730
#
#                                   (inventory * 365) / cost of products sold  EBITDA (profit on operating activities - depreciation) / total assets  EBITDA (profit on operating activities - depreciation) / sales  current assets / total liabilities  short-term liabilities / total assets  (short-term liabilities * 365) / cost of products sold)  equity / fixed assets  constant capital / fixed assets  working capital  (sales - cost of products sold) / sales  (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)  total costs /total sales  long-term liabilities / equity  sales / inventory  sales / receivables  (short-term liabilities *365) / sales  sales / short-term liabilities  sales / fixed assets
# net profit / total assets                                          0.000051                                           0.490985                                                               0.000253                                         0.036325                              -0.158139                                          -0.100931                    -0.008174                        -0.008157         0.002983                                 0.000061                                           0.004398                                                             -0.000061                        0.000287          -0.000375             0.009186                              -0.000848                        0.049427             -0.041161
# total liabilities / total assets                                  -0.000523                                          -0.100451                                                              -0.000514                                        -0.020642                               0.986503                                           0.628823                    -0.066144                        -0.065868        -0.009709                                -0.000655                                          -0.000743                                                              0.000656                        0.000979          -0.000016            -0.002368                               0.005456                       -0.017961             -0.104069

# %% [markdown]
# #### 3. b. Use `seaborn` to plot a heatmap of your correlation matrix
#
# You will need to play around with the plotting options to get a clear view of where the correlations are

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.heatmap(corr_matrix);

# %% [markdown]
# Because there are a lot of columns, and their names are long, the default heatmap doesn't look great. Let's play around with the options

# %%
fig, ax = plt.subplots(figsize=(18, 18))

corr_matrix_to_plot = corr_matrix.copy()

# reduce column names to N chars max
max_chars = 15
corr_matrix_to_plot.columns = [c[:max_chars] for c in corr_matrix_to_plot.columns]
# same for index (i.e. row labels)
corr_matrix_to_plot.index = [c[:max_chars] for c in corr_matrix_to_plot.index]

sns.heatmap(
    data=corr_matrix_to_plot,
    vmin=-1,
    vmax=1, # explicitly set the boundaries
    center=0,
    square=True,
    linewidths=1,
    ax=ax
)

plt.show()

# %% [markdown]
# ### 3. c. Dig into it a bit more, and find the top few strongest correlated column pairs

# %%
# A few ways to approach this, one is let's extract the column-pairs and their respective correlations,
# and find the top N unique highest ones

# Extract each possible column pair. Many ways to do this, but one clever one is to get a 'mask'
# where the correlations are close to 1 or -1, and use stack() to get the column-index list
# as per this SO answer: https://stackoverflow.com/a/26858881
correlation_pairs = corr_matrix[(corr_matrix > 0.9) | (corr_matrix < -0.9)].stack()

# this is a Series with a multi-index (basically pairs of column names)
correlation_pairs
# Out:
# net profit / total assets                                                                                            net profit / total assets                                                                                              1.000000
# total liabilities / total assets                                                                                     total liabilities / total assets                                                                                       1.000000
#                                                                                                                      working capital / total assets                                                                                        -0.985782
#                                                                                                                      short-term liabilities / total assets                                                                                  0.986503
# working capital / total assets                                                                                       total liabilities / total assets                                                                                      -0.985782
#                                                                                                                      working capital / total assets                                                                                         1.000000
#                                                                                                                      short-term liabilities / total assets                                                                                 -0.999136
# current assets / short-term liabilities                                                                              current assets / short-term liabilities                                                                                1.000000
#                                                                                                                      (current assets - inventory - receivables) / short-term liabilities                                                    0.970127
#                                                                                                                      (current assets - inventory) / short-term liabilities                                                                  0.988127
# [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365    1.000000
# retained earnings / total assets                                                                                     retained earnings / total assets                                                                                       1.000000
# EBIT / total assets                                                                                                  EBIT / total assets                                                                                                    1.000000
#                                                                                                                      (gross profit + extraordinary items + financial expenses) / total assets                                               0.994389
#                                                                                                                      (gross profit + interest) / total assets                                                                               1.000000
#                                                                                                                      gross profit / total assets                                                                                            1.000000
#                                                                                                                      profit on operating activities / total assets                                                                          0.957465
#                                                                                                                      gross profit (in 3 years) / total assets                                                                               0.972130
# book value of equity / total liabilities                                                                             book value of equity / total liabilities                                                                               1.000000
#                                                                                                                      (gross profit + depreciation) / total liabilities                                                                      0.911975
#                                                                                                                      total assets / total liabilities                                                                                       0.995457
#                                                                                                                      (net profit + depreciation) / total liabilities                                                                        0.941082
# sales / total assets                                                                                                 sales / total assets                                                                                                   1.000000
#                                                                                                                      equity / total assets                                                                                                  0.912149
#                                                                                                                      total sales / total assets                                                                                             0.999916
#                                                                                                                      constant capital / total assets                                                                                        0.912139
# equity / total assets                                                                                                sales / total assets                                                                                                   0.912149
#                                                                                                                      equity / total assets                                                                                                  1.000000
#                                                                                                                      total sales / total assets                                                                                             0.912117
#                                                                                                                      constant capital / total assets                                                                                        0.999990
# (gross profit + extraordinary items + financial expenses) / total assets                                             EBIT / total assets                                                                                                    0.994389
#                                                                                                                      (gross profit + extraordinary items + financial expenses) / total assets                                               1.000000
#                                                                                                                      (gross profit + interest) / total assets                                                                               0.994389
#                                                                                                                      gross profit / total assets                                                                                            0.994389
#                                                                                                                      profit on operating activities / total assets                                                                          0.962788
#                                                                                                                      gross profit (in 3 years) / total assets                                                                               0.964061
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / total assets                                                  0.900098
# gross profit / short-term liabilities                                                                                gross profit / short-term liabilities                                                                                  1.000000
# (gross profit + depreciation) / sales                                                                                (gross profit + depreciation) / sales                                                                                  1.000000
#                                                                                                                      (inventory * 365) / sales                                                                                              0.994441
#                                                                                                                      net profit / sales                                                                                                     0.912277
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.990439
#                                                                                                                      profit on sales / sales                                                                                                0.959589
#                                                                                                                      profit on operating activities / sales                                                                                 0.958001
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.992787
#                                                                                                                      (receivables * 365) / sales                                                                                            0.992046
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.988168
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.994566
#                                                                                                                      total costs /total sales                                                                                               0.994566
#                                                                                                                      (short-term liabilities *365) / sales                                                                                  0.942309
# (gross profit + interest) / total assets                                                                             EBIT / total assets                                                                                                    1.000000
#                                                                                                                      (gross profit + extraordinary items + financial expenses) / total assets                                               0.994389
#                                                                                                                      (gross profit + interest) / total assets                                                                               1.000000
#                                                                                                                      gross profit / total assets                                                                                            1.000000
#                                                                                                                      profit on operating activities / total assets                                                                          0.957465
#                                                                                                                      gross profit (in 3 years) / total assets                                                                               0.972130
# (total liabilities * 365) / (gross profit + depreciation)                                                            (total liabilities * 365) / (gross profit + depreciation)                                                              1.000000
# (gross profit + depreciation) / total liabilities                                                                    book value of equity / total liabilities                                                                               0.911975
#                                                                                                                      (gross profit + depreciation) / total liabilities                                                                      1.000000
#                                                                                                                      total assets / total liabilities                                                                                       0.907904
#                                                                                                                      (net profit + depreciation) / total liabilities                                                                        0.980925
# total assets / total liabilities                                                                                     book value of equity / total liabilities                                                                               0.995457
#                                                                                                                      (gross profit + depreciation) / total liabilities                                                                      0.907904
#                                                                                                                      total assets / total liabilities                                                                                       1.000000
#                                                                                                                      (net profit + depreciation) / total liabilities                                                                        0.946312
# gross profit / total assets                                                                                          EBIT / total assets                                                                                                    1.000000
#                                                                                                                      (gross profit + extraordinary items + financial expenses) / total assets                                               0.994389
#                                                                                                                      (gross profit + interest) / total assets                                                                               1.000000
#                                                                                                                      gross profit / total assets                                                                                            1.000000
#                                                                                                                      profit on operating activities / total assets                                                                          0.957465
#                                                                                                                      gross profit (in 3 years) / total assets                                                                               0.972130
# gross profit / sales                                                                                                 gross profit / sales                                                                                                   1.000000
#                                                                                                                      net profit / sales                                                                                                     0.998123
#                                                                                                                      (gross profit + interest) / sales                                                                                      0.999987
# (inventory * 365) / sales                                                                                            (gross profit + depreciation) / sales                                                                                  0.994441
#                                                                                                                      (inventory * 365) / sales                                                                                              1.000000
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.998352
#                                                                                                                      profit on sales / sales                                                                                                0.949538
#                                                                                                                      profit on operating activities / sales                                                                                 0.949431
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.999633
#                                                                                                                      (receivables * 365) / sales                                                                                            0.999336
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.997067
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.999996
#                                                                                                                      total costs /total sales                                                                                               0.999996
#                                                                                                                      (short-term liabilities *365) / sales                                                                                  0.961081
# sales (n) / sales (n-1)                                                                                              sales (n) / sales (n-1)                                                                                                1.000000
# profit on operating activities / total assets                                                                        EBIT / total assets                                                                                                    0.957465
#                                                                                                                      (gross profit + extraordinary items + financial expenses) / total assets                                               0.962788
#                                                                                                                      (gross profit + interest) / total assets                                                                               0.957465
#                                                                                                                      gross profit / total assets                                                                                            0.957465
#                                                                                                                      profit on operating activities / total assets                                                                          1.000000
#                                                                                                                      gross profit (in 3 years) / total assets                                                                               0.908403
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / total assets                                                  0.971255
# net profit / sales                                                                                                   (gross profit + depreciation) / sales                                                                                  0.912277
#                                                                                                                      gross profit / sales                                                                                                   0.998123
#                                                                                                                      net profit / sales                                                                                                     1.000000
#                                                                                                                      (gross profit + interest) / sales                                                                                      0.998111
#                                                                                                                      profit on sales / sales                                                                                                0.901708
# gross profit (in 3 years) / total assets                                                                             EBIT / total assets                                                                                                    0.972130
#                                                                                                                      (gross profit + extraordinary items + financial expenses) / total assets                                               0.964061
#                                                                                                                      (gross profit + interest) / total assets                                                                               0.972130
#                                                                                                                      gross profit / total assets                                                                                            0.972130
#                                                                                                                      profit on operating activities / total assets                                                                          0.908403
#                                                                                                                      gross profit (in 3 years) / total assets                                                                               1.000000
# (equity - share capital) / total assets                                                                              (equity - share capital) / total assets                                                                                1.000000
# (net profit + depreciation) / total liabilities                                                                      book value of equity / total liabilities                                                                               0.941082
#                                                                                                                      (gross profit + depreciation) / total liabilities                                                                      0.980925
#                                                                                                                      total assets / total liabilities                                                                                       0.946312
#                                                                                                                      (net profit + depreciation) / total liabilities                                                                        1.000000
# profit on operating activities / financial expenses                                                                  profit on operating activities / financial expenses                                                                    1.000000
# working capital / fixed assets                                                                                       working capital / fixed assets                                                                                         1.000000
# logarithm of total assets                                                                                            logarithm of total assets                                                                                              1.000000
# (total liabilities - cash) / sales                                                                                   (gross profit + depreciation) / sales                                                                                  0.990439
#                                                                                                                      (inventory * 365) / sales                                                                                              0.998352
#                                                                                                                      (total liabilities - cash) / sales                                                                                     1.000000
#                                                                                                                      profit on sales / sales                                                                                                0.930162
#                                                                                                                      profit on operating activities / sales                                                                                 0.929988
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.999528
#                                                                                                                      (receivables * 365) / sales                                                                                            0.999764
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.999782
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.998201
#                                                                                                                      total costs /total sales                                                                                               0.998201
#                                                                                                                      (short-term liabilities *365) / sales                                                                                  0.975288
# (gross profit + interest) / sales                                                                                    gross profit / sales                                                                                                   0.999987
#                                                                                                                      net profit / sales                                                                                                     0.998111
#                                                                                                                      (gross profit + interest) / sales                                                                                      1.000000
# (current liabilities * 365) / cost of products sold                                                                  (current liabilities * 365) / cost of products sold                                                                    1.000000
#                                                                                                                      (short-term liabilities * 365) / cost of products sold)                                                                0.935035
# operating expenses / short-term liabilities                                                                          operating expenses / short-term liabilities                                                                            1.000000
#                                                                                                                      operating expenses / total liabilities                                                                                 0.900847
#                                                                                                                      sales / short-term liabilities                                                                                         0.970138
# operating expenses / total liabilities                                                                               operating expenses / short-term liabilities                                                                            0.900847
#                                                                                                                      operating expenses / total liabilities                                                                                 1.000000
#                                                                                                                      sales / short-term liabilities                                                                                         0.918149
# profit on sales / total assets                                                                                       profit on sales / total assets                                                                                         1.000000
# total sales / total assets                                                                                           sales / total assets                                                                                                   0.999916
#                                                                                                                      equity / total assets                                                                                                  0.912117
#                                                                                                                      total sales / total assets                                                                                             1.000000
#                                                                                                                      constant capital / total assets                                                                                        0.912104
# (current assets - inventories) / long-term liabilities                                                               (current assets - inventories) / long-term liabilities                                                                 1.000000
# constant capital / total assets                                                                                      sales / total assets                                                                                                   0.912139
#                                                                                                                      equity / total assets                                                                                                  0.999990
#                                                                                                                      total sales / total assets                                                                                             0.912104
#                                                                                                                      constant capital / total assets                                                                                        1.000000
# profit on sales / sales                                                                                              (gross profit + depreciation) / sales                                                                                  0.959589
#                                                                                                                      (inventory * 365) / sales                                                                                              0.949538
#                                                                                                                      net profit / sales                                                                                                     0.901708
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.930162
#                                                                                                                      profit on sales / sales                                                                                                1.000000
#                                                                                                                      profit on operating activities / sales                                                                                 0.999870
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.940748
#                                                                                                                      (receivables * 365) / sales                                                                                            0.937550
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.922785
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.950356
#                                                                                                                      total costs /total sales                                                                                               0.950356
# (current assets - inventory - receivables) / short-term liabilities                                                  current assets / short-term liabilities                                                                                0.970127
#                                                                                                                      (current assets - inventory - receivables) / short-term liabilities                                                    1.000000
#                                                                                                                      (current assets - inventory) / short-term liabilities                                                                  0.989420
# total liabilities / ((profit on operating activities + depreciation) * (12/365))                                     total liabilities / ((profit on operating activities + depreciation) * (12/365))                                       1.000000
# profit on operating activities / sales                                                                               (gross profit + depreciation) / sales                                                                                  0.958001
#                                                                                                                      (inventory * 365) / sales                                                                                              0.949431
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.929988
#                                                                                                                      profit on sales / sales                                                                                                0.999870
#                                                                                                                      profit on operating activities / sales                                                                                 1.000000
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.940639
#                                                                                                                      (receivables * 365) / sales                                                                                            0.937441
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.922619
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.950249
#                                                                                                                      total costs /total sales                                                                                               0.950249
# rotation receivables + inventory turnover in days                                                                    (gross profit + depreciation) / sales                                                                                  0.992787
#                                                                                                                      (inventory * 365) / sales                                                                                              0.999633
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.999528
#                                                                                                                      profit on sales / sales                                                                                                0.940748
#                                                                                                                      profit on operating activities / sales                                                                                 0.940639
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      1.000000
#                                                                                                                      (receivables * 365) / sales                                                                                            0.999956
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.998759
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.999559
#                                                                                                                      total costs /total sales                                                                                               0.999559
#                                                                                                                      (short-term liabilities *365) / sales                                                                                  0.968191
# (receivables * 365) / sales                                                                                          (gross profit + depreciation) / sales                                                                                  0.992046
#                                                                                                                      (inventory * 365) / sales                                                                                              0.999336
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.999764
#                                                                                                                      profit on sales / sales                                                                                                0.937550
#                                                                                                                      profit on operating activities / sales                                                                                 0.937441
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.999956
#                                                                                                                      (receivables * 365) / sales                                                                                            1.000000
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.999173
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.999238
#                                                                                                                      total costs /total sales                                                                                               0.999238
#                                                                                                                      (short-term liabilities *365) / sales                                                                                  0.970483
# net profit / inventory                                                                                               net profit / inventory                                                                                                 1.000000
#                                                                                                                      sales / inventory                                                                                                     -0.981920
# (current assets - inventory) / short-term liabilities                                                                current assets / short-term liabilities                                                                                0.988127
#                                                                                                                      (current assets - inventory - receivables) / short-term liabilities                                                    0.989420
# ...
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                         1.000000
#                                                                                                                      (sales - cost of products sold) / sales                                                                                0.996864
#                                                                                                                      total costs /total sales                                                                                              -0.996864
#                                                                                                                      (short-term liabilities *365) / sales                                                                                 -0.979281
# current assets / total liabilities                                                                                   current assets / total liabilities                                                                                     1.000000
# short-term liabilities / total assets                                                                                total liabilities / total assets                                                                                       0.986503
#                                                                                                                      working capital / total assets                                                                                        -0.999136
#                                                                                                                      short-term liabilities / total assets                                                                                  1.000000
# (short-term liabilities * 365) / cost of products sold)                                                              (current liabilities * 365) / cost of products sold                                                                    0.935035
#                                                                                                                      (short-term liabilities * 365) / cost of products sold)                                                                1.000000
# equity / fixed assets                                                                                                equity / fixed assets                                                                                                  1.000000
#                                                                                                                      constant capital / fixed assets                                                                                        0.999917
#                                                                                                                      sales / receivables                                                                                                    0.973201
#                                                                                                                      sales / fixed assets                                                                                                   0.973310
# constant capital / fixed assets                                                                                      equity / fixed assets                                                                                                  0.999917
#                                                                                                                      constant capital / fixed assets                                                                                        1.000000
#                                                                                                                      sales / receivables                                                                                                    0.975627
#                                                                                                                      sales / fixed assets                                                                                                   0.973437
# working capital                                                                                                      working capital                                                                                                        1.000000
# (sales - cost of products sold) / sales                                                                              (gross profit + depreciation) / sales                                                                                 -0.994566
#                                                                                                                      (inventory * 365) / sales                                                                                             -0.999996
#                                                                                                                      (total liabilities - cash) / sales                                                                                    -0.998201
#                                                                                                                      profit on sales / sales                                                                                               -0.950356
#                                                                                                                      profit on operating activities / sales                                                                                -0.950249
#                                                                                                                      rotation receivables + inventory turnover in days                                                                     -0.999559
#                                                                                                                      (receivables * 365) / sales                                                                                           -0.999238
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                         0.996864
#                                                                                                                      (sales - cost of products sold) / sales                                                                                1.000000
#                                                                                                                      total costs /total sales                                                                                              -1.000000
#                                                                                                                      (short-term liabilities *365) / sales                                                                                 -0.960360
# (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)                        (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)                          1.000000
# total costs /total sales                                                                                             (gross profit + depreciation) / sales                                                                                  0.994566
#                                                                                                                      (inventory * 365) / sales                                                                                              0.999996
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.998201
#                                                                                                                      profit on sales / sales                                                                                                0.950356
#                                                                                                                      profit on operating activities / sales                                                                                 0.950249
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.999559
#                                                                                                                      (receivables * 365) / sales                                                                                            0.999238
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.996864
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -1.000000
#                                                                                                                      total costs /total sales                                                                                               1.000000
#                                                                                                                      (short-term liabilities *365) / sales                                                                                  0.960360
# long-term liabilities / equity                                                                                       long-term liabilities / equity                                                                                         1.000000
# sales / inventory                                                                                                    net profit / inventory                                                                                                -0.981920
#                                                                                                                      sales / inventory                                                                                                      1.000000
# sales / receivables                                                                                                  equity / fixed assets                                                                                                  0.973201
#                                                                                                                      constant capital / fixed assets                                                                                        0.975627
#                                                                                                                      sales / receivables                                                                                                    1.000000
#                                                                                                                      sales / fixed assets                                                                                                   0.954745
# (short-term liabilities *365) / sales                                                                                (gross profit + depreciation) / sales                                                                                  0.942309
#                                                                                                                      (inventory * 365) / sales                                                                                              0.961081
#                                                                                                                      (total liabilities - cash) / sales                                                                                     0.975288
#                                                                                                                      rotation receivables + inventory turnover in days                                                                      0.968191
#                                                                                                                      (receivables * 365) / sales                                                                                            0.970483
#                                                                                                                      EBITDA (profit on operating activities - depreciation) / sales                                                        -0.979281
#                                                                                                                      (sales - cost of products sold) / sales                                                                               -0.960360
#                                                                                                                      total costs /total sales                                                                                               0.960360
#                                                                                                                      (short-term liabilities *365) / sales                                                                                  1.000000
# sales / short-term liabilities                                                                                       operating expenses / short-term liabilities                                                                            0.970138
#                                                                                                                      operating expenses / total liabilities                                                                                 0.918149
#                                                                                                                      sales / short-term liabilities                                                                                         1.000000
# sales / fixed assets                                                                                                 equity / fixed assets                                                                                                  0.973310
#                                                                                                                      constant capital / fixed assets                                                                                        0.973437
#                                                                                                                      sales / receivables                                                                                                    0.954745
#                                                                                                                      sales / fixed assets                                                                                                   1.000000
# dtype: float64

# %% [markdown]
# We can make it into a DataFrame and remove items where the two are the same (columns correlated with themselves) and remove duplicates

# %%
# make into a DataFrame
corr_df = correlation_pairs.reset_index(name="correlation")

# extract only those that aren't the self-correlations
corr_df = corr_df[corr_df["level_0"] != corr_df["level_1"]]

# sort by the absolute correlation value and find the top 10 pairs
corr_df["abs_correlation"] = abs(corr_df["correlation"])
corr_df.sort_values("abs_correlation", ascending=False).head(10)
# Out:
#                                       level_0                                   level_1  correlation  abs_correlation
# 50   (gross profit + interest) / total assets                       EBIT / total assets     1.000000         1.000000
# 53   (gross profit + interest) / total assets               gross profit / total assets     1.000000         1.000000
# 65                gross profit / total assets                       EBIT / total assets     1.000000         1.000000
# 14                        EBIT / total assets  (gross profit + interest) / total assets     1.000000         1.000000
# 15                        EBIT / total assets               gross profit / total assets     1.000000         1.000000
# 67                gross profit / total assets  (gross profit + interest) / total assets     1.000000         1.000000
# 246                  total costs /total sales   (sales - cost of products sold) / sales    -1.000000         1.000000
# 235   (sales - cost of products sold) / sales                  total costs /total sales    -1.000000         1.000000
# 82                  (inventory * 365) / sales   (sales - cost of products sold) / sales    -0.999996         0.999996
# 227   (sales - cost of products sold) / sales                 (inventory * 365) / sales    -0.999996         0.999996

# %% [markdown]
# Some of these are duplicates, so let's remove those. We can Google the problem and use a clever StackOverflow solution (https://stackoverflow.com/a/51303604)

# %%
import numpy as np

df1 = pd.DataFrame(np.sort(corr_df[['level_0','level_1']], axis=1))

# use negative indexing (~ operator) to only keep what ISN'T a duplicate pair
corr_df = corr_df.reset_index(drop=True)[~df1.duplicated()]

# show top 10
corr_df.sort_values("abs_correlation", ascending=False).head(10)
# Out:
#                                                level_0                                   level_1  correlation  abs_correlation
# 6                                  EBIT / total assets  (gross profit + interest) / total assets     1.000000         1.000000
# 34            (gross profit + interest) / total assets               gross profit / total assets     1.000000         1.000000
# 7                                  EBIT / total assets               gross profit / total assets     1.000000         1.000000
# 100            (sales - cost of products sold) / sales                  total costs /total sales    -1.000000         1.000000
# 50                           (inventory * 365) / sales   (sales - cost of products sold) / sales    -0.999996         0.999996
# 51                           (inventory * 365) / sales                  total costs /total sales     0.999996         0.999996
# 17                               equity / total assets           constant capital / total assets     0.999990         0.999990
# 43                                gross profit / sales         (gross profit + interest) / sales     0.999987         0.999987
# 82   rotation receivables + inventory turnover in days               (receivables * 365) / sales     0.999956         0.999956
# 95                               equity / fixed assets           constant capital / fixed assets     0.999917         0.999917

# %% [markdown]
# So again, there are some strongly duplicated columns, which we want to bear in mind when choosing our features

# %% [markdown]
# ### 4. Look at the distribution of your variables for bankrupt vs. non-bankrupt companies
#
# We're looking for cases where the distribution of a feature is different for bankrupt companies, suggesting that it would be a good feature to separate the classes.
#
# You could start by comparing the average value of each feature for bankrupt vs. non-bankrupt companies, or as a bonus plot the actual distribution (using histograms, box plots or similar).

# %%
# columns to look at are all but the last one
feature_cols = df.columns[:-1]

# group by the target and average each feature column
# and transpose using `.T` to see them side-by-side rather than above-below
# and rename to give columns meaningful names
feature_means = (
    df
        .groupby("bankruptcy_label")
        [feature_cols]
        .mean()
        .T
        .rename(columns={0:"non-bankrupt",
                         1:"bankrupt"})
)

feature_means.head()
# Out:
# bankruptcy_label                                    non-bankrupt    bankrupt
# net profit / total assets                               0.044393   -0.207890
# total liabilities / total assets                        0.490395    2.300058
# working capital / total assets                          0.188765   -1.594335
# current assets / short-term liabilities                 2.607667    3.162163
# [(cash + short-term securities + receivables - ...   -248.210388 -635.598537

# %%
# calculate % diff between averages
# and sort by this column to see the ones that differ the most
# between bankrupt and non-bankrupt companies

feature_means["diff"] = (feature_means["bankrupt"] - feature_means["non-bankrupt"]) / feature_means["non-bankrupt"]
feature_means.sort_values("diff", ascending=False).head(10)
# Out:
# bankruptcy_label                                    non-bankrupt     bankrupt      diff
# (current liabilities * 365) / cost of products ...    187.625382  1454.603303  6.752700
# short-term liabilities / total assets                   0.399219     2.173729  4.444952
# total liabilities / total assets                        0.490395     2.300058  3.690215
# (short-term liabilities * 365) / cost of produc...      0.526354     2.030019  2.856757
# (total liabilities * 365) / (gross profit + dep...   1657.417894  5423.393672  2.272194
# [(cash + short-term securities + receivables - ...   -248.210388  -635.598537  1.560725
# (current assets - inventory - receivables) / sh...      0.800044     1.473633  0.841940
# operating expenses / total liabilities                  3.575546     5.919992  0.655689
# current assets / total liabilities                      2.017607     2.591571  0.284478
# long-term liabilities / equity                          0.275009     0.348118  0.265842

# %% [markdown]
# ### 5. Based on findings from above, combined with your domain knowledge, choose 5 features with which to build a first predictive model
#
# It is usually a good idea to choose uncorrelated features, and in the case of classification those that suggest a separation between labels 0 and 1 (i.e. features that are distinctly different for bankrupt and non-bankrupt companies).

# %% [markdown]
# Let's take the top 5 uncorrelated features from part 4. i.e. those that suggest a separation but are not strongly correlated

# %%
top_10_separation = feature_means.sort_values("diff", ascending=False).head(10)
top_10_colnames = top_10_separation.index

# get correlation matrix for the top 10 from above
corr_matrix_10 = df[top_10_colnames].corr()

sns.heatmap(corr_matrix_10,
            vmin=-1,
            vmax=1,
            center=0);

# %% [markdown]
# Eyeballing the above we'll use:
#
# - 'total liabilities / total assets'
# - '(total liabilities * 365) / (gross profit + depreciation)'
# - (current assets - inventory - receivables) / short-term liabilities'
# - 'operating expenses / total liabilities'
# - 'long-term liabilities / equity'
#
# Let's verify the correlation matrix

# %%
features_to_use = ['(short-term liabilities * 365) / cost of products sold)',
                   '(total liabilities * 365) / (gross profit + depreciation)',
                   '(current assets - inventory - receivables) / short-term liabilities',
                   'operating expenses / total liabilities',
                   'long-term liabilities / equity']

sns.heatmap(df[features_to_use].corr(),
            vmin=-1,
            vmax=1,
            center=0);

# %%
# are they correlated with the outcome?
corr_list=features_to_use
corr_list.append('bankruptcy_label')
df[corr_list].corr()[['bankruptcy_label']].sort_values('bankruptcy_label', ascending=False)
# Out:
#                                                     bankruptcy_label
# bankruptcy_label                                            1.000000
# (short-term liabilities * 365) / cost of produc...          0.034025
# operating expenses / total liabilities                      0.027680
# (current assets - inventory - receivables) / sh...          0.010320
# (total liabilities * 365) / (gross profit + dep...          0.008643
# long-term liabilities / equity                              0.002221

# %%
features_to_use
# Out:
# ['(short-term liabilities * 365) / cost of products sold)',
#  '(total liabilities * 365) / (gross profit + depreciation)',
#  '(current assets - inventory - receivables) / short-term liabilities',
#  'operating expenses / total liabilities',
#  'long-term liabilities / equity',
#  'bankruptcy_label']

# %%
# there's a lot of imbalance with bankruptcy
df["bankruptcy_label"].value_counts()
# Out:
# 0    6756
# 1     271
# Name: bankruptcy_label, dtype: int64

# %% [markdown]
# # Part 2 - Prediction

# %% [markdown]
# ### 1. Using the features you selected above, create training and test sets
#
# Ensure that both your training and test sets have the same distribution of bankrupt/non-bankrupt companies. You can use a specific parameter when splitting your data to achieve this.

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# drop missing values for features only
X = df.dropna(subset=features_to_use)[features_to_use]
y = df.dropna(subset=features_to_use)["bankruptcy_label"]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    stratify=y, # stratify to ensure train/test have ~4% bankrupt companies
                                                    random_state=42 # reproducibility
                                                   )

print(len(X_train), len(y_train), len(X_test), len(y_test))
# Out:
# 4876 4876 2091 2091

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.961034
# 1    0.038966
# Name: bankruptcy_label, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.961263
# 1    0.038737
# Name: bankruptcy_label, dtype: float64

# %% [markdown]
# ### 2. Choose an appropriate metric for evaluating your predictions
#
# Think about:
#
# - the problem itself: is it classification (binary? multi-class?)/regression?
# - the distribution of your target: does this change which metrics are appropriate?

# %% [markdown]
# This is a binary classification problem with an imbalanced dataset. We can't use accuracy because of the imbalance, because even if we predicted "no bankruptcy" in all cases, we'd get 96% accuracy!
#
# F1 score or ROC-AUC are more appropriate metrics.

# %% [markdown]
# ### 3. Train a predictive model
#
# - Think about best practices:
#     - Only train using the training set
#     - Use cross-validation to get a better estimate of performance on unseen data
#     - Use grid search to optimise your models' hyperparameters

# %%
#importing and training the model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='newton-cg', class_weight='balanced', max_iter=20000)
lr.fit(X_train, y_train)
# Out:
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\sklearn\utils\optimize.py:204: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# LogisticRegression(class_weight='balanced', max_iter=20000, solver='newton-cg')

# %%
# Predicting on the test data
pred_test = lr.predict(X_test)

# %%
#Calculating and printing the f1 score 
accuracy_test = metrics.accuracy_score(y_test, pred_test)
print('The accuracy score for the testing data:', accuracy_test)
f1_test = metrics.f1_score(y_test, pred_test)
print('The f1 score for the testing data:', f1_test)
# Out:
# The accuracy score for the testing data: 1.0
# The f1 score for the testing data: 1.0

# %%
#Plotting the confusion matrix
metrics.confusion_matrix(y_test, pred_test)
# Out:
# array([[2010,    0],
#        [   0,   81]], dtype=int64)

# %%
# this cell will take a while.
from sklearn.model_selection import GridSearchCV, StratifiedKFold
lr = LogisticRegression(solver='newton-cg')

#Setting the range for class weights
weights = np.linspace(0.0,0.99,200)

#Creating a dictionary grid for grid search
param_grid = {'class_weight': [{0:x, 1:1.0-x} for x in weights]}

#Fitting grid search to the train data with 5 folds
gridsearch = GridSearchCV(estimator= lr, 
                          param_grid= param_grid,
                          cv=StratifiedKFold(), 
                          n_jobs=-1, 
                          scoring='f1', 
                          verbose=2).fit(X_train, y_train)

#Plotting the score for different values of weight
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
weigh_data = pd.DataFrame({ 'score': gridsearch.cv_results_['mean_test_score'], 'weight': (1- weights)})
sns.lineplot(weigh_data['weight'], weigh_data['score'])
plt.xlabel('Weight for class 1')
plt.ylabel('F1 score')
plt.xticks([round(i/10,1) for i in range(0,11,1)])
plt.title('Scoring for different class weights', fontsize=24)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  2.0min finished
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\aaron.thompson\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# Text(0.5, 1.0, 'Scoring for different class weights')

# %%
# the optimal class weights:
gridsearch.best_params_
# Out:
# {'class_weight': {0: 0.11442211055276383, 1: 0.8855778894472361}}

# %%
# refit the model:
lr2 = LogisticRegression(solver='newton-cg', 
                        class_weight={0: 0.11442211055276383, 1: 0.8855778894472361})

# %%
# make a confusion matrix
y_pred_lr_train = gridsearch.best_estimator_.predict(X_train)
metrics.confusion_matrix(y_train, y_pred_lr_train)
# Out:
# array([[4686,    0],
#        [   0,  190]], dtype=int64)

# %%
# predict on the testing data
y_preds = gridsearch.best_estimator_.predict(X_test)
print(len(y_test))
print(len(y_preds))
# Out:
# 2091
# 2091

# %%
# score your model
print(metrics.accuracy_score(y_test, y_preds))
print(metrics.precision_score(y_test, y_preds))
print(metrics.f1_score(y_test, y_preds))
# Out:
# 1.0
# 1.0
# 1.0

# %% [markdown]
# High accuracy - but only because of imbalance classes!

# %% [markdown]
# ### 4. Evaluate your models on the *training* set
#
# Go deeper than the single metric you used for training. Try showing the confusion matrix for both models - what can you see?

# %%
from sklearn.metrics import confusion_matrix

y_pred_lr_train = gridsearch.best_estimator_.predict(X_train)
confusion_matrix(y_train, y_pred_lr_train)
# Out:
# array([[4686,    0],
#        [   0,  190]], dtype=int64)

# %% [markdown]
# It's clear that the model is just predicting "not bankrupt" for pretty much everything!

# %% [markdown]
# # Part 3 - Improvements
#
# Time to improve your models. There are many different things you can do here including:
#
# - choosing more/different features
# - trying to tune more hyperparameters (if they exist)
# - trying a third model
# - tuning other aspects of the prediction process (e.g. changing the cutoff for predicting 1 instead of 0 from the default of 0.5, that is: if your model predicts a company is 50% or more likely to be bankrupt it will predict "bankrupt". Changing this threshold may help improve its performance)
#
# Further reading is available for example in this excellent article [Learning from Imbalanced Classes](https://www.svds.com/learning-imbalanced-classes/)

# %% [markdown]
# ### 1. Try something to improve your best performing model from above

# %%
from sklearn.metrics import roc_auc_score

# let's try changing the decision threshold from 0.5
# define a function to try a threshold and return the AUC
def try_threshold(model, X, y, threshold):
    # predict probability of bankruptcy not just 0 or 1
    predicted_proba = model.predict_proba(X)
    
    # only return 1 if probability over chosen threshold
    predicted = (predicted_proba[:,1] >= threshold).astype('int')
    
    # evaluate these predictions
    return roc_auc_score(y, predicted)

thresholds_to_try = np.arange(0.05, 1, 0.05)
scores = []

for t in thresholds_to_try:
    scores.append(try_threshold(gridsearch.best_estimator_, X_train, y_train, t))

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(thresholds_to_try, scores)

ax.set(title="ROC-AUC of different thresholds",
       xlabel="Threshold",
       ylabel="ROC-AUC")

plt.show()

# %% [markdown]
# Because the model is never "confident" in non-bankrupt predictions, changing the threshold seems to improve our score.
#
# Try our predictions with a much lower threshold:

# %%
proba = gridsearch.best_estimator_.predict_proba(X_test)
y_preds = (proba[:,1] >= 0.5).astype('int')

print(metrics.accuracy_score(y_test, y_preds))
print(metrics.precision_score(y_test, y_preds))
print(metrics.f1_score(y_test, y_preds))
# Out:
# 1.0
# 1.0
# 1.0

# %% [markdown]
# That looks a little healthier.

# %% [markdown]
# ## Try a different type of model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# these parameters are from gridsearch
rf_model= RandomForestClassifier(max_depth=3, min_samples_leaf=25, n_estimators=91)

# %%
# fit
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_leaf=25, n_estimators=91)

# %%
# predict
y_preds=rf_model.predict(X_test)

# %%
# score your model
print(metrics.accuracy_score(y_test, y_preds))
print(metrics.precision_score(y_test, y_preds))
print(metrics.f1_score(y_test, y_preds))
# Out:
# 1.0
# 1.0
# 1.0

# %%
from sklearn.metrics import roc_auc_score

# let's try changing the decision threshold from 0.5
# define a function to try a threshold and return the AUC
def try_threshold(model, X, y, threshold):
    # predict probability of bankruptcy not just 0 or 1
    predicted_proba = model.predict_proba(X)
    
    # only return 1 if probability over chosen threshold
    predicted = (predicted_proba[:,1] >= threshold).astype('int')
    
    # evaluate these predictions
    return roc_auc_score(y, predicted)

thresholds_to_try = np.arange(0.05, 1, 0.05)
scores = []

for t in thresholds_to_try:
    scores.append(try_threshold(rf_model, X_train, y_train, t))

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(thresholds_to_try, scores)

ax.set(title="ROC-AUC of different thresholds",
       xlabel="Threshold",
       ylabel="ROC-AUC")

plt.show()

# %%
# Try our predictions with a much lower threshold:
proba = rf_model.predict_proba(X_train)
y_pred_rf_v2 = (proba[:,1] >= 0.05).astype('int')
confusion_matrix(y_train, y_pred_rf_v2)
# Out:
# array([[4647,   39],
#        [   0,  190]], dtype=int64)

# %%
# and now the testing data
proba = rf_model.predict_proba(X_test)
y_pred_rf_v2 = (proba[:,1] >= 0.05).astype('int')
cm = confusion_matrix(y_test, y_pred_rf_v2)
cm
# Out:
# array([[1973,   37],
#        [   0,   81]], dtype=int64)

# %%
tn = cm[0][0]
tp = cm[1][1]
fn = cm[1][0]
fp = cm[0][1]

# %%
# Precision = TP / (TP+FP)
round(tp / (tp + fp), 3)
# Out:
# 0.686

# %%
# Recall = TP / (TP+FN)
round(tp / (tp + fn), 3)
# Out:
# 1.0
